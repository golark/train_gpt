# %%
from train_gpt.model_ape import GPT, GPTConfig
import torch
model = GPT(GPTConfig(vocab_size=50304))

# load checkpoint with device-aware mapping to avoid CUDA-only deserialization errors
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
weights = torch.load('../models/inc_max_lr_model.pt', map_location=device)
model.load_state_dict(weights['model'])
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[5], line 7
#       5 # load checkpoint with device-aware mapping to avoid CUDA-only deserialization errors
#       6 device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# ----> 7 weights = torch.load('../models/inc_max_lr_model.pt', map_location=device)
#       8 model.load_state_dict(weights['model'])
#
# File ~/golark/train_gpt/venv/lib/python3.9/site-packages/torch/serialization.py:1529, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1521                 return _load(
#    1522                     opened_zipfile,
#    1523                     map_location,
#    (...)
#    1526                     **pickle_load_args,
#    1527                 )
#    1528             except pickle.UnpicklingError as e:
# ...
